# %% [markdown]
# 1. Create an activator in workspace
# 2. Create an object in activator
#
#     Object name: Redmond Packages
#     Unique Identifier: PackageId
#     Properties: City, ColdChainType, SpecialCare, Temperature
#
# 3. Create a rule
#
# 4. Create an action
